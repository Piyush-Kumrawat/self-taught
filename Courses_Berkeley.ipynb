# %%
import pandas as pd
from glob import glob
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')
import seaborn as sns
color_pal = sns.color_palette()
import plotly.express as px

# %%
df = pd.read_csv('/home/n-3331/Documents/Datasets/Courses_Berkeley_2018-01-15.csv')

# %%
df
# Out:
#          index  Year              Field  \
# 0            0  1967  Aerospace Studies
# 1            1  2011      Public Health
# 2            2  2011      Public Health
# 3            3  2011      Public Health
# 4            4  1971  Aerospace Studies
# ...        ...   ...                ...
# 305665  305665  1969            Zoology
# 305666  305666  1919        Agriculture
# 305667  305667  1918        Agriculture
# 305668  305668  1917        Agriculture
# 305669  305669  1919        Agriculture
#
#                                                      Name Number  \
# 0                        Officer Basic Military Training      22
# 1                              Drugs, Health, and Society    103
# 2       Policy, Planning , and Evaluation of Health Pr...    105
# 3       Cognitive Science C1 Molecularand Cell Biology...     1B
# 4                     Officer Advanced Military Training     432
# ...                                                   ...    ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 305670 entries, 0 to 305669
# Data columns (total 15 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   index        305670 non-null  int64
#  1   Year         305670 non-null  int64
#  2   Field        305670 non-null  object
#  3   Name         305670 non-null  object
#  4   Number       305669 non-null  object
#  5   Area         305670 non-null  object
#  6   GenArea      305670 non-null  object
#  7   Description  295025 non-null  object
#  8   Profs1       160543 non-null  float64
#  9   Profs2       25857 non-null   float64
#  10  Fall         305670 non-null  bool
#  11  Winter       305670 non-null  bool
#  12  Spring       305670 non-null  bool
#  13  Summer       305670 non-null  bool
#  14  Taught       305670 non-null  bool
# dtypes: bool(5), float64(2), int64(2), object(6)
# memory usage: 24.8+ MB

# %%
df.describe()
# Out:
#                index           Year         Profs1        Profs2
# count  305670.000000  305670.000000  160543.000000  25857.000000
# mean   152834.500000    1972.155445    5204.033349   6493.435395
# std     88239.472729      25.962040    5328.043624   4899.208121
# min         0.000000    1900.000000       0.000000      1.000000
# 25%     76417.250000    1955.000000     226.000000   2483.000000
# 50%    152834.500000    1977.000000    3325.000000   5352.000000
# 75%    229251.750000    1992.000000    8673.000000   9440.000000
# max    305669.000000    2011.000000   20381.000000  20299.000000

# %%
df['Year'].value_counts().sort_index().plot.bar(figsize=(15,5))
# Out:
# <AxesSubplot: >

# %%
from sentence_transformers import SentenceTransformer

# Load the pre-trained model
model = SentenceTransformer(model_name_or_path='all-MiniLM-L12-v2')

# Encode the sentence 'Hello world'
embedding_hello_world = model.encode(['Hello world'])

# Print the resulting numerical vector
print(embedding_hello_world)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 from sentence_transformers import SentenceTransformer
#       3 # Load the pre-trained model
#       4 model = SentenceTransformer(model_name_or_path='all-MiniLM-L12-v2')
#
# ModuleNotFoundError: No module named 'sentence_transformers'

# %%
pip install SentenceTransformer

# %%
sudo apt install python3-SentenceTransformer

# %%
sudo pip install sentence-transformers

# %%
sudo apt install sentence-transformers

# %%
from sentence_transformers import SentenceTransformer
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 from sentence_transformers import SentenceTransformer
#
# ModuleNotFoundError: No module named 'sentence_transformers'
